# %% [markdown]
# <a href="https://colab.research.google.com/github/gortiz7791/Cloud_curious/blob/master/Predict_House_PricesPart_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# House Sales Data, ETL, Build Predictive Model(linear regression),
# Assess Model, Deploy Model   'houseSmallData.csv'
# R^2 = 0.75  Percentage of the Price explained by the indep. variables
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### data_description.txt
# SalePrice — the property’s sale price in dollars. This is the target variable that you’re trying to predict.
# MSSubClass — The building class
# MSZoning — The general zoning classification
# MasVnrArea - Masonary Veneer Area in sq ft
# LotFrontage — Linear feet of street connected to property
# LotArea — Lot size in square feet
# Street — Type of road access
# Alley — Type of alley access
# LotShape — General shape of property
# LandContour — Flatness of the property
# Utilities — Type of utilities available
# LotConfig — Lot configuration

# %% [markdown]
# $$Y = X\beta + e $$

# %%
#data = pd.read_csv('houseSmallData.csv')
file = 'https://raw.githubusercontent.com/GAdevopsES/Python100/refs/heads/master/houseSmallData.csv'
data = pd.read_csv(file)
train = data.iloc[0:100,:]
train.shape
train
train.shape
# Out:
# (100, 82)

# %%
salePrice = train['SalePrice']
salePrice.describe()
plt.hist(salePrice)
# Out:
# (array([ 2., 17., 35., 17., 11.,  8.,  5.,  3.,  1.,  1.]),
#  array([ 40000.,  79878., 119756., 159634., 199512., 239390., 279268.,
#         319146., 359024., 398902., 438780.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.log(salePrice))
np.log(salePrice).skew()
target = np.log(salePrice)

# %%
plt.scatter(train['GrLivArea'],y=target)

# %%
plt.scatter(train['GarageArea'],y=target)

# %%
nulls = train.isnull().sum().sort_values(ascending=False)[0:20]
type(nulls)
data = train.select_dtypes(include=[np.number]).interpolate().dropna(axis=1)
sum(data.isnull().sum() != 0)
data.shape
# Out:
# (100, 39)

# %%
numeric = data.select_dtypes(include=[np.number])
numeric.head()
corr = numeric.corr()
cols = corr['SalePrice'].sort_values(ascending=False)[:5].index
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageArea', 'GarageCars'], dtype='object')

# %%
X = data[cols]
Y = X['SalePrice']
X = X.drop(['SalePrice'], axis = 1)
X
# Out:
#     OverallQual  GrLivArea  GarageArea  GarageCars
# 0             7       1710         548           2
# 1             6       1262         460           2
# 2             7       1786         608           2
# 3             7       1717         642           3
# 4             8       2198         836           3
# ..          ...        ...         ...         ...
# 95            6       1470         420           2
# 96            7       1588         472           2
# 97            4        960         432           1
# 98            5        835         366           1
# 99            4       1225           0           0
#
# [100 rows x 4 columns]

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(X, Y)
predictions = model.predict(X)
print(f"R^2 is: {model.score(X,Y)}")
# Out:
# R^2 is: 0.7916699059969976

# %%
plt.hist(Y - predictions)
# Out:
# (array([ 5.,  4.,  4., 14., 30., 22.,  8.,  9.,  2.,  2.]),
#  array([-82657.24950314, -65380.38192448, -48103.51434583, -30826.64676717,
#         -13549.77918851,   3727.08839014,  21003.9559688 ,  38280.82354746,
#          55557.69112611,  72834.55870477,  90111.42628343]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(predictions, Y, color = 'r')

# %%
train[['SalePrice', 'OverallQual', 'MasVnrArea']]
# Out:
#     SalePrice  OverallQual  MasVnrArea
# 0      208500            7       196.0
# 1      181500            6         0.0
# 2      223500            7       162.0
# 3      140000            7         0.0
# 4      250000            8       350.0
# ..        ...          ...         ...
# 95     185000            6        68.0
# 96     214000            7       183.0
# 97      94750            4        48.0
# 98      83000            5         0.0
# 99     128950            4         0.0
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Interpolate Missing Data

# %%
file = 'https://raw.githubusercontent.com/GAdevopsES/Python100/master/houseSmallData.csv'
data = pd.read_csv(file)
train = data.iloc[0:100,:]
numeric = train.select_dtypes(include=[np.number])
numeric.head()
# Out:
#    Unnamed: 0  Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0           0   1          60         65.0     8450            7            5
# 1           1   2          20         80.0     9600            6            8
# 2           2   3          60         68.0    11250            7            5
# 3           3   4          70         60.0     9550            7            5
# 4           4   5          60         84.0    14260            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ...  OpenPorchSF  EnclosedPorch  \
# 0       2003          2003       196.0  ...           61              0
# 1       1976          1976         0.0  ...            0              0
# 2       2001          2002       162.0  ...           42              0
# 3       1915          1970         0.0  ...           35            272
# 4       2000          2000       350.0  ...           84              0
#
#    3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  MoSold  YrSold  \
# 0          0            0         0     NaN        0       2    2008
# 1          0            0         0     NaN        0       5    2007
# 2          0            0         0     NaN        0       9    2008
# 3          0            0         0     NaN        0       2    2006
# 4          0            0         0     NaN        0      12    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 40 columns]

# %%
corr = numeric.corr()
cols = corr['SalePrice'].sort_values(ascending=False)[:3]
cols
# Out:
# SalePrice      1.000000
# OverallQual    0.855061
# GrLivArea      0.735129
# Name: SalePrice, dtype: float64
